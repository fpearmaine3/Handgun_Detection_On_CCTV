# %%
# !unzip yolov5-master.zip
# Out:
# Archive:  yolov5-master.zip
#    creating: yolov5-master/
#   inflating: __MACOSX/._yolov5-master
#   inflating: yolov5-master/.DS_Store
#   inflating: __MACOSX/yolov5-master/._.DS_Store
#   inflating: yolov5-master/LICENSE
#   inflating: __MACOSX/yolov5-master/._LICENSE
#   inflating: yolov5-master/requirements.txt
#   inflating: __MACOSX/yolov5-master/._requirements.txt
#   inflating: yolov5-master/.pre-commit-config.yaml
#   inflating: __MACOSX/yolov5-master/._.pre-commit-config.yaml
#   inflating: yolov5-master/val.py
#   inflating: __MACOSX/yolov5-master/._val.py
#    creating: yolov5-master/utils/
#   inflating: __MACOSX/yolov5-master/._utils
#    creating: yolov5-master/models/
#   inflating: __MACOSX/yolov5-master/._models
#   inflating: yolov5-master/export.py
#   inflating: __MACOSX/yolov5-master/._export.py
#   inflating: yolov5-master/README.md
#   inflating: __MACOSX/yolov5-master/._README.md
#   inflating: yolov5-master/.gitignore
# ...

# %%
# !unzip star_Handgun_Dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: star_Handgun_Dataset/train/labels/armas--2460-_jpg.rf.f9e4b4f0ccf2d9c419ede5809936713f.txt
#   inflating: __MACOSX/star_Handgun_Dataset/train/labels/._armas--2460-_jpg.rf.f9e4b4f0ccf2d9c419ede5809936713f.txt
#   inflating: star_Handgun_Dataset/train/labels/armas--319-_jpg.rf.574e006ef2727ab61dc0c53b224acc39.txt
#   inflating: __MACOSX/star_Handgun_Dataset/train/labels/._armas--319-_jpg.rf.574e006ef2727ab61dc0c53b224acc39.txt
#   inflating: star_Handgun_Dataset/train/labels/armas--317-_jpg.rf.10ba3d69ba081e632a00eae740f43b60.txt
#   inflating: __MACOSX/star_Handgun_Dataset/train/labels/._armas--317-_jpg.rf.10ba3d69ba081e632a00eae740f43b60.txt
#   inflating: star_Handgun_Dataset/train/labels/armas--1605-_jpg.rf.4f5cb70f39df0a70782b1a2ea668b786.txt
#   inflating: __MACOSX/star_Handgun_Dataset/train/labels/._armas--1605-_jpg.rf.4f5cb70f39df0a70782b1a2ea668b786.txt
# ...

# %%
# !cd ../
# !ls

# %%
# Install everthing necessary for YOLOv5 to compile
import torch
from IPython.display import Image, clear_output
# %cd yolov5-master
# %pip install -qr requirements.txt
# Out:
# /content/yolov5-master
#      |████████████████████████████████| 596 kB 9.6 MB/s

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data custom_data.yaml --cfg ./models/Coord_yolos.yaml --weights ''
# Out:
# train: weights=, cfg=./models/Coord_yolos.yaml, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python train.py --img 416 --batch 32 --epochs 100 --data custom_data.yaml --cfg ./models/Coord_yolos.yaml --weights ''
# Out:
# train: weights=, cfg=./models/Coord_yolos.yaml, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --resume
# Out:
# train: weights=yolov5s.pt, cfg=models/Coord_yolos.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=True, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Resuming training from ./runs/train/exp2/weights/last.pt
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
